# %% [markdown]
# <a href="https://colab.research.google.com/github/PRIYANKAMANOJAROUT/DATASCIENCE-PRACTICAL/blob/main/prac7_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading data from different source files formats (csv,excel)

# %%
import pandas as pd
data=pd.read_csv('/content/PRIYANKA.csv')

# %%
data
# Out:
#     SR NO      NAME   DEPT  SALARY
# 0       1  PRIYANKA   ACCT   45000
# 1       2    ANKITA   ACCT   45000
# 2       3  VISHAKHA   ACCT   45000
# 3       4     ALMAS     HR   45000
# 4       5  JAISHREE  SALES   45000
# 5       6      TANU     HR   40000
# 6       7   PRADNYA     HR   50000
# 7       8      RIYA  SALES   50000
# 8       9  PRIYANKA  SALES   50000
# 9      10  VISHAKHA  SALES   50000
# 10     11   PRADNYA   ACCT   45000
# 11     12  JAISHREE   ACCT   50000
# 12     13  RAJSHREE   ACCT   45000
# 13     14   ANUSUYA     IT   60000
# 14     15  ARMISTHA     IT   60000

# %%
data1=pd.read_excel('/content/PRIYANKA1.xlsx')

# %%
data1
# Out:
#     SR NO      NAME   DEPT  SALARY
# 0       1  PRIYANKA   ACCT   45000
# 1       2    ANKITA   ACCT   45000
# 2       3  VISHAKHA   ACCT   45000
# 3       4     ALMAS     HR   45000
# 4       5  JAISHREE  SALES   45000
# 5       6      TANU     HR   40000
# 6       7   PRADNYA     HR   50000
# 7       8      RIYA  SALES   50000
# 8       9  PRIYANKA  SALES   50000
# 9      10  VISHAKHA  SALES   50000
# 10     11   PRADNYA   ACCT   45000
# 11     12  JAISHREE   ACCT   50000
# 12     13  RAJSHREE   ACCT   45000
# 13     14   ANUSUYA     IT   60000
# 14     15  ARMISTHA     IT   60000

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('/content/nature.jpg')
plt.imshow(img)

# %%
import seaborn as sns
import pandas as pd
data=pd.DataFrame({'Roll no':[1,2,3,4,5],'Name':['Priyanka','Almas','Tanu','Jaishree','Ankita']
                   ,'Marks':[58,55,52,53,54],'Class':['A','B','A','B','A']})

# %% [markdown]
# # Summarizing the data

# %%
print(data)
# Out:
#    Roll no      Name  Marks Class
# 0        1  Priyanka     58     A
# 1        2     Almas     55     B
# 2        3      Tanu     52     A
# 3        4  Jaishree     53     B
# 4        5    Ankita     54     A

# %%
data.isnull().sum()
# Out:
# Roll no    0
# Name       0
# Marks      0
# Class      0
# dtype: int64

# %%
data.describe()
# Out:
#         Roll no      Marks
# count  5.000000   5.000000
# mean   3.000000  54.400000
# std    1.581139   2.302173
# min    1.000000  52.000000
# 25%    2.000000  53.000000
# 50%    3.000000  54.000000
# 75%    4.000000  55.000000
# max    5.000000  58.000000

# %%
data.describe(include='object')
# Out:
#             Name Class
# count          5     5
# unique         5     2
# top     Priyanka     A
# freq           1     3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  5 non-null      int64
#  1   Name     5 non-null      object
#  2   Marks    5 non-null      int64
#  3   Class    5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %%
data.nunique()
# Out:
# Roll no    5
# Name       5
# Marks      5
# Class      2
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Name'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Name, dtype: bool

# %%
data['Name'].value_counts()
# Out:
# Priyanka    1
# Almas       1
# Tanu        1
# Jaishree    1
# Ankita      1
# Name: Name, dtype: int64

# %%
data.value_counts()
# Out:
# Roll no  Name      Marks  Class
# 1        Priyanka  58     A        1
# 2        Almas     55     B        1
# 3        Tanu      52     A        1
# 4        Jaishree  53     B        1
# 5        Ankita    54     A        1
# dtype: int64

# %%
data['Class'].duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Class, dtype: bool

# %%
data['Class'].value_counts()
# Out:
# A    3
# B    2
# Name: Class, dtype: int64

# %%
 data['Class'].value_counts()
# Out:
# A    3
# B    2
# Name: Class, dtype: int64

# %%
data['Marks'].mean()
# Out:
# 54.4

# %%
data['Marks'].var()
# Out:
# 5.300000000000001

# %%
correlation=data.corr()
# Out:
# <ipython-input-54-7f2487af4b08>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=data.corr()

# %%
sns.heatmap(correlation,annot=True,fmt='.2f',cmap='coolwarm')
# Out:
# <Axes: >
